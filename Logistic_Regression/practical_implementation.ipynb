# %%
import seaborn as sns
import pandas as pd
import numpy as np

# %%
df = sns.load_dataset("iris")
df.head()

# %%
df.isnull().sum()

# %%
df["species"].unique()

# %%
df = df[df["species"] != "setosa"]
df.head()

# %%
df["species"] = df["species"].map({"versicolor" : 0, "virginica" : 1})
df.head()

# %%
X = df.iloc[:,:-1]
y =  df.iloc[:,-1]

# %%
X

# %%
y

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=25, random_state = 42)

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(solver = "lbfgs")

# %%
from sklearn.model_selection import GridSearchCV
parameters = {"C":np.logspace(-3, 3, 10), "max_iter":[50, 100, 150, 200, 250, 300]}
classification_regressor = GridSearchCV(classifier, param_grid = parameters, scoring = "accuracy", cv = 10)

# %%
classification_regressor.fit(X_train, y_train)

# %%
classification_regressor.best_params_

# %%
classification_regressor.best_score_

# %%
y_pred = classification_regressor.predict(X_test)
y_pred

# %%
from sklearn.metrics import accuracy_score, classification_report
score = accuracy_score(y_pred, y_test)
score

# %%
print(classification_report(y_pred, y_test))

# %%
# EDA
sns.pairplot(df, hue = "species")

# %%
# if all these correlations are very good...then accuracy is high
df.corr()
