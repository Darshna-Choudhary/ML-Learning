# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import r2_score

# %%
df = pd.read_csv("Salary_Data.csv")
df.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
df["Exp"] = df["YearsExperience"].astype(int)
df["Sal"] = df["Salary"].astype(int)

# %%
plt.figure(figsize=(6,4))
plt.scatter(df["YearsExperience"], df["Salary"])
plt.xlabel("Exp")
plt.ylabel("Salary")
plt.tight_layout()

# %%
X = df[["YearsExperience"]]
y = df["Salary"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 42, test_size = 0.30)

# %%
model = LinearRegression()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
score = r2_score(y_test, y_pred)
print(score)
# Out:
# 0.9414466227178214

# %%
X_sorted = np.sort(X.values, axis=0)
y_sorted_pred = model.predict(X_sorted)
# Out:
# C:\Users\cucky\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
plt.figure(figsize=(6,4))
plt.scatter(X, y, label='Actual Data')
plt.plot(X_sorted, y_sorted_pred, color='red', linewidth=2, label='Best Fit Line')
plt.xlabel("Experience")
plt.ylabel("Salary")
plt.title("Salary vs Experience")
plt.tight_layout()
